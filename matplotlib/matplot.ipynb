# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
a=np.array([1,2,3,4,5,6,7,8])
b=np.array([8,7,6,5,8,7,6,5])
plt.plot(a,b)
plt.plot(a,b,marker='o')

# %%
x=np.array([1,8,7])
plt.plot(x,marker='o')

# %%
a=np.array([1,2,3,4,5,6,7,8])
b=np.array([8,7,6,5,8,7,6,5])
plt.plot(a,b)
plt.plot(a,b,'o:b')  #for dotted line
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 a=np.array([1,2,3,4,5,6,7,8])
#       2 b=np.array([8,7,6,5,8,7,6,5])
#       3 plt.plot(a,b)
#
# NameError: name 'np' is not defined

# %% [markdown]
# for changing color

# %%
a=np.array([1,2,3,4,5,6,7,8])
b=np.array([8,7,6,5,8,7,6,5])
plt.plot(a,b,color='g',ms=30,marker='*',mfc='r') # ms for size ,mfc for inner color,mec for outer color of star

# %% [markdown]
# # for dotted line

# %%
plt.plot(a,b,color='g',ms=30,marker='*',mfc='r',ls='dotted')

# %%
plt.plot(a)
plt.plot(b)

# %%
plt.xlabel("x axis")
plt.ylabel("y axis")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 plt.xlabel("x axis")
#       2 plt.ylabel("y axis")
#
# NameError: name 'plt' is not defined

# %%
# Out:
# Requirement already satisfied: matplotlib in c:\users\aashi\appdata\local\programs\python\python312\lib\site-packages (3.9.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\aashi\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\aashi\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\aashi\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\aashi\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy>=1.23 in c:\users\aashi\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\aashi\appdata\roaming\python\python312\site-packages (from matplotlib) (24.0)
# Requirement already satisfied: pillow>=8 in c:\users\aashi\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\aashi\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\aashi\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\aashi\appdata\local\programs\python\python312\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
