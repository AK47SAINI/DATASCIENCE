# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn as sl

# %%
data=pd.read_csv('Salary_dataset.csv')
# print(data)
data1=data.drop(columns=['Unnamed: 0'])

print(data1)
# Out:
#     YearsExperience    Salary
# 0               1.2   39344.0
# 1               1.4   46206.0
# 2               1.6   37732.0
# 3               2.1   43526.0
# 4               2.3   39892.0
# 5               3.0   56643.0
# 6               3.1   60151.0
# 7               3.3   54446.0
# 8               3.3   64446.0
# 9               3.8   57190.0
# 10              4.0   63219.0
# 11              4.1   55795.0
# 12              4.1   56958.0
# 13              4.2   57082.0
# 14              4.6   61112.0
# 15              5.0   67939.0
# 16              5.2   66030.0
# 17              5.4   83089.0
# 18              6.0   81364.0
# 19              6.1   93941.0
# 20              6.9   91739.0
# 21              7.2   98274.0
# 22              8.0  101303.0
# 23              8.3  113813.0
# 24              8.8  109432.0
# 25              9.1  105583.0
# 26              9.6  116970.0
# 27              9.7  112636.0
# 28             10.4  122392.0
# 29             10.6  121873.0

# %%
x=data1.iloc[:,:-1].values
y=data1.iloc[:,1].values


from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.2)
print(x_test)
# Out:
# [[10.6]
#  [ 1.6]
#  [ 5. ]
#  [ 9.1]
#  [ 9.7]
#  [ 3.3]]

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
lr.score(x_train,y_train)
# Out:
# 0.9460502865450687

# %%
y_pred=lr.predict(x_test)
x_pred=lr.predict(x_train)
print(y_pred,x_pred)
# Out:
# [127446.67296312  39790.29550665  72904.92699021 112837.27672038
#  118681.03521748  56347.61124843] [ 63165.32949504  35894.45650859  53425.73199988 102123.7194757
#   64139.28924456  69009.08799214  46608.01375327 125498.75346409
#   65113.24899408  91410.16223102  74852.84648924  83618.48423489
#   64139.28924456  54399.6917494   94332.04147957 109915.39747183
#   56347.61124843  82644.52448537  61217.40999601  37842.37600762
#  105045.59872425 117707.07546796  76800.76598827  44660.09425423]

# %%
lr.score(x_test,y_test)
# Out:
# 0.9744995764224843

# %%
plt.scatter(x_train,y_train,color='red')
plt.plot(x_train,x_pred,color='green')
plt.title("salary vs exp")
plt.xlabel("years of exp")
plt.ylabel("salary")
plt.show()
