# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn as sl

# %%
data=pd.read_csv('Salary_dataset.csv')
# print(data)
data1=data.drop(columns=['Unnamed: 0'])

print(data1)
# Out:
#     YearsExperience    Salary
# 0               1.2   39344.0
# 1               1.4   46206.0
# 2               1.6   37732.0
# 3               2.1   43526.0
# 4               2.3   39892.0
# 5               3.0   56643.0
# 6               3.1   60151.0
# 7               3.3   54446.0
# 8               3.3   64446.0
# 9               3.8   57190.0
# 10              4.0   63219.0
# 11              4.1   55795.0
# 12              4.1   56958.0
# 13              4.2   57082.0
# 14              4.6   61112.0
# 15              5.0   67939.0
# 16              5.2   66030.0
# 17              5.4   83089.0
# 18              6.0   81364.0
# 19              6.1   93941.0
# 20              6.9   91739.0
# 21              7.2   98274.0
# 22              8.0  101303.0
# 23              8.3  113813.0
# 24              8.8  109432.0
# 25              9.1  105583.0
# 26              9.6  116970.0
# 27              9.7  112636.0
# 28             10.4  122392.0
# 29             10.6  121873.0

# %%
x=data1.iloc[:,:-1].values
y=data1.iloc[:,1].values


from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.2)
print(x_test)
# Out:
# [[10.4]
#  [ 5.2]
#  [ 8.3]
#  [ 3.3]
#  [ 1.6]
#  [ 5.4]]

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
lr.score(x_train,y_train)
# Out:
# 0.9620260690924359

# %%
y_pred=lr.predict(x_test)
x_pred=lr.predict(x_train)
print(y_pred,x_pred)
# Out:
# [121930.40005243  73369.44184367 102319.24385274  55626.01480585
#   39750.31692991  75237.17100555] [ 62163.06687242  71501.7126818   63096.93145336  63096.93145336
#   55626.01480585  60295.33771054  64030.79603429 114459.48340493
#   53758.28564398  99517.65010993  92046.73346243 109790.16050024
#  115393.34798587  89245.13971961 106988.56675743  36014.85860616
#   80840.35849117  37882.58776804 123798.12921431  44419.6398346
#   67766.25435805  52824.42106304  81774.22307211  46287.36899648]

# %%
lr.score(x_test,y_test)
# Out:
# 0.9361562896393927

# %%
plt.scatter(x_train,y_train,color='red')
plt.plot(x_train,x_pred,color='green')
plt.title("salary vs exp")
plt.xlabel("years of exp")
plt.ylabel("salary")
plt.show()
